# %%
from PlotFile import plot_file

# %%
plot_file("ptc_4_4")
plot_file("ptc_gmres_4_4")

# %%
plot_file("tr_4_16_True")
plot_file("tr_gmres_4_16_True")

# %%
plot_file("Ptc_4_4")
