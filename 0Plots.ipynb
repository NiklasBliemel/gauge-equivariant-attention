# %%
from PlotFile import plot_file

# %%
plot_file("PtcOnly")
plot_file("PtcOnly_gmres")

# %%
plot_file("Tr_4_128")
plot_file("Tr_gmres_4_128")

# %%
plot_file("SuperPtc")

# %%
plot_file("Tr_gmres_4_128_False")
plot_file("Tr_gmres_4_128_True")
plot_file("Tr_gmres_4_16_True")

# %%
plot_file("Tr_4_32_False")
plot_file("Tr_4_32_True")

# %%
plot_file("Tr_4_64_False")
plot_file("Tr_4_64_True")

# %%
plot_file("Tr_4_128_False")
plot_file("Tr_4_128_True")

# %%
plot_file("Tr_4_256_False")
plot_file("Tr_4_256_True")
