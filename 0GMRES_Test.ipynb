# %%
from GMRES import GmresTest
from Operators import d_wc
from Constants import *
from Preconditioner import *

# %%
gmres_test = GmresTest(d_wc, NUM_OF_LATTICES, LATTICE, GAUGE_DOF, NON_GAUGE_DOF, max_iter=1000, tol=1e-6)

# %%
gmres_test() # x0 = zeros
# Out:
# res: 8.5523e-07
# Using GMRES: error: 8.4496e-07 in time 7334.8ms and 60 iterations

# %%
PtcOnly = ptc("PtcOnly")
gmres_test(PtcOnly)
# Out:
# res: 7.3055e-03
# Using GMRES: error: 7.3501e-03 in time 3740.1ms and 19 iterations

# %%
PtcOnly_gmres = ptc("PtcOnly_gmres")
gmres_test(PtcOnly_gmres)
# Out:
# res: 6.5459e-07
# Using GMRES: error: 6.6690e-07 in time 8438.6ms and 34 iterations

# %%
tr = transformer("Tr_4_32_True")
gmres_test(tr)
# Out:
# res: 8.2503e-03
# Using GMRES: error: 8.3099e-03 in time 4419.7ms and 21 iterations

# %%
tr = transformer("Tr_4_32_False")
gmres_test(tr)
# Out:
# res: 6.8200e-02
# Using GMRES: error: 6.7299e-02 in time 8786.5ms and 30 iterations

# %%
tr = transformer("Tr_gmres_4_128_True")
gmres_test(tr)
# Out:
# res: 8.8453e-03
# Using GMRES: error: 8.6310e-03 in time 9078.8ms and 18 iterations

# %%
tr = transformer("Tr_gmres_4_16_True")
gmres_test(tr)
# Out:
# res: 9.4030e-07
# Using GMRES: error: 9.1525e-07 in time 29454.9ms and 42 iterations

# %%
tr = transformer("Tr_gmres_4_128_False")
gmres_test(tr)
# Out:
# res: 8.1918e-03
# Using GMRES: error: 8.2960e-03 in time 12935.1ms and 20 iterations
